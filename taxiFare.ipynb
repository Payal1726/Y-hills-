# %%
import pandas as pd

# %%
df=pd.read_csv("TaxiFare.csv")

# %%
df.head()
# Out:
#   unique_id  amount      date_time_of_pickup  longitude_of_pickup  \
# 0   26:21.0     4.5  2009-06-15 17:26:21 UTC           -73.844311
# 1   52:16.0    16.9  2010-01-05 16:52:16 UTC           -74.016048
# 2   35:00.0     5.7  2011-08-18 00:35:00 UTC           -73.982738
# 3   30:42.0     7.7  2012-04-21 04:30:42 UTC           -73.987130
# 4   51:00.0     5.3  2010-03-09 07:51:00 UTC           -73.968095
#
#    latitude_of_pickup  longitude_of_dropoff  latitude_of_dropoff  \
# 0           40.721319            -73.841610            40.712278
# 1           40.711303            -73.979268            40.782004
# 2           40.761270            -73.991242            40.750562
# 3           40.733143            -73.991567            40.758092
# 4           40.768008            -73.956655            40.783762
#
#    no_of_passenger
# 0                1
# 1                1
# 2                2
# 3                1
# 4                1

# %%
df.tail()
# Out:
#       unique_id  amount      date_time_of_pickup  longitude_of_pickup  \
# 49995   25:15.0    15.0  2013-06-12 23:25:15 UTC           -73.999973
# 49996   19:18.0     7.5  2015-06-22 17:19:18 UTC           -73.984756
# 49997   53:00.0     6.9  2011-01-30 04:53:00 UTC           -74.002698
# 49998   09:00.0     4.5  2012-11-06 07:09:00 UTC           -73.946062
# 49999   13:14.0    10.9  2010-01-13 08:13:14 UTC           -73.932603
#
#        latitude_of_pickup  longitude_of_dropoff  latitude_of_dropoff  \
# 49995           40.748531            -74.016899            40.705993
# 49996           40.768211            -73.987366            40.760597
# 49997           40.739428            -73.998108            40.759483
# 49998           40.777567            -73.953450            40.779687
# 49999           40.763805            -73.932603            40.763805
#
#        no_of_passenger
# 49995                1
# 49996                1
# 49997                1
# 49998                2
# 49999                1

# %%
df.head(10)
# Out:
#   unique_id  amount      date_time_of_pickup  longitude_of_pickup  \
# 0   26:21.0     4.5  2009-06-15 17:26:21 UTC           -73.844311
# 1   52:16.0    16.9  2010-01-05 16:52:16 UTC           -74.016048
# 2   35:00.0     5.7  2011-08-18 00:35:00 UTC           -73.982738
# 3   30:42.0     7.7  2012-04-21 04:30:42 UTC           -73.987130
# 4   51:00.0     5.3  2010-03-09 07:51:00 UTC           -73.968095
# 5   50:45.0    12.1  2011-01-06 09:50:45 UTC           -74.000964
# 6   35:00.0     7.5  2012-11-20 20:35:00 UTC           -73.980002
# 7   22:00.0    16.5  2012-01-04 17:22:00 UTC           -73.951300
# 8   10:00.0     9.0  2012-12-03 13:10:00 UTC           -74.006462
# 9   11:00.0     8.9  2009-09-02 01:11:00 UTC           -73.980658
#
#    latitude_of_pickup  longitude_of_dropoff  latitude_of_dropoff  \
# 0           40.721319            -73.841610            40.712278
# 1           40.711303            -73.979268            40.782004
# 2           40.761270            -73.991242            40.750562
# 3           40.733143            -73.991567            40.758092
# 4           40.768008            -73.956655            40.783762
# 5           40.731630            -73.972892            40.758233
# 6           40.751662            -73.973802            40.764842
# 7           40.774138            -73.990095            40.751048
# 8           40.726713            -73.993078            40.731628
# 9           40.733873            -73.991540            40.758138
#
#    no_of_passenger
# 0                1
# 1                1
# 2                2
# 3                1
# 4                1
# 5                1
# 6                1
# 7                1
# 8                1
# 9                2

# %%
df.tail(10)
# Out:
#       unique_id  amount      date_time_of_pickup  longitude_of_pickup  \
# 49990   16:00.0     4.5  2013-07-18 00:16:00 UTC           -74.002857
# 49991   56:19.0    10.5  2013-10-17 19:56:19 UTC           -73.991685
# 49992   41:47.0     6.1  2009-06-06 10:41:47 UTC           -73.984673
# 49993   27:00.0     7.3  2011-04-07 14:27:00 UTC           -73.982363
# 49994   57:00.0     8.5  2012-10-13 19:57:00 UTC           -73.976212
# 49995   25:15.0    15.0  2013-06-12 23:25:15 UTC           -73.999973
# 49996   19:18.0     7.5  2015-06-22 17:19:18 UTC           -73.984756
# 49997   53:00.0     6.9  2011-01-30 04:53:00 UTC           -74.002698
# 49998   09:00.0     4.5  2012-11-06 07:09:00 UTC           -73.946062
# 49999   13:14.0    10.9  2010-01-13 08:13:14 UTC           -73.932603
#
#        latitude_of_pickup  longitude_of_dropoff  latitude_of_dropoff  \
# 49990           40.734137            -74.001610            40.739282
# 49991           40.739494            -73.985357            40.731971
# 49992           40.768434            -73.988215            40.760082
# 49993           40.765060            -73.969167            40.761268
# 49994           40.744832            -73.981567            40.724635
# 49995           40.748531            -74.016899            40.705993
# 49996           40.768211            -73.987366            40.760597
# 49997           40.739428            -73.998108            40.759483
# 49998           40.777567            -73.953450            40.779687
# 49999           40.763805            -73.932603            40.763805
#
#        no_of_passenger
# 49990                1
# 49991                1
# 49992                1
# 49993                1
# 49994                1
# 49995                1
# 49996                1
# 49997                1
# 49998                2
# 49999                1

# %%
df.sample()
# Out:
#       unique_id  amount      date_time_of_pickup  longitude_of_pickup  \
# 28584   14:00.0     3.3  2009-12-02 18:14:00 UTC           -74.006228
#
#        latitude_of_pickup  longitude_of_dropoff  latitude_of_dropoff  \
# 28584           40.734583            -74.005325            40.731562
#
#        no_of_passenger
# 28584                1

# %%
df.sample(5)
# Out:
#       unique_id  amount      date_time_of_pickup  longitude_of_pickup  \
# 13602   14:00.0    23.5  2012-11-17 14:14:00 UTC           -74.004857
# 20980   44:43.0     5.7  2009-05-27 08:44:43 UTC           -73.992051
# 16227   21:16.0     9.5  2014-11-15 23:21:16 UTC           -73.985075
# 46825   42:41.0     8.5  2013-07-05 15:42:41 UTC           -73.976541
# 35240   35:20.0     3.5  2015-01-17 23:35:20 UTC           -73.988518
#
#        latitude_of_pickup  longitude_of_dropoff  latitude_of_dropoff  \
# 13602           40.730163            -73.982155            40.771745
# 20980           40.749345            -73.985876            40.740937
# 16227           40.755080            -73.971866            40.763409
# 46825           40.727489            -73.996581            40.716502
# 35240           40.745869            -73.986588            40.751347
#
#        no_of_passenger
# 13602                2
# 20980                1
# 16227                1
# 46825                4
# 35240                1

# %%
df.isnull().sum()
# Out:
# unique_id               0
# amount                  0
# date_time_of_pickup     0
# longitude_of_pickup     0
# latitude_of_pickup      0
# longitude_of_dropoff    0
# latitude_of_dropoff     0
# no_of_passenger         0
# dtype: int64

# %%
df.shape
# Out:
# (50000, 8)

# %%
df.columns
# Out:
# Index(['unique_id', 'amount', 'date_time_of_pickup', 'longitude_of_pickup',
#        'latitude_of_pickup', 'longitude_of_dropoff', 'latitude_of_dropoff',
#        'no_of_passenger'],
#       dtype='object')

# %%
df.dtypes
# Out:
# unique_id                object
# amount                  float64
# date_time_of_pickup      object
# longitude_of_pickup     float64
# latitude_of_pickup      float64
# longitude_of_dropoff    float64
# latitude_of_dropoff     float64
# no_of_passenger           int64
# dtype: object

# %%
df.describe()
# Out:
#              amount  longitude_of_pickup  latitude_of_pickup  \
# count  50000.000000         50000.000000        50000.000000
# mean      11.364171           -72.509756           39.933759
# std        9.685557            10.393860            6.224857
# min       -5.000000           -75.423848          -74.006893
# 25%        6.000000           -73.992062           40.734880
# 50%        8.500000           -73.981840           40.752678
# 75%       12.500000           -73.967148           40.767360
# max      200.000000            40.783472          401.083332
#
#        longitude_of_dropoff  latitude_of_dropoff  no_of_passenger
# count          50000.000000         50000.000000     50000.000000
# mean             -72.504616            39.926251         1.667840
# std               10.407570             6.014737         1.289195
# min              -84.654241           -74.006377         0.000000
# 25%              -73.991152            40.734372         1.000000
# 50%              -73.980082            40.753372         1.000000
# 75%              -73.963584            40.768167         2.000000
# max               40.851027            43.415190         6.000000

# %%
df.describe(include="all")
# Out:
#        unique_id        amount      date_time_of_pickup  longitude_of_pickup  \
# count      50000  50000.000000                    50000         50000.000000
# unique      3597           NaN                    49555                  NaN
# top      26:00.0           NaN  2011-09-03 01:30:00 UTC                  NaN
# freq         457           NaN                        3                  NaN
# mean         NaN     11.364171                      NaN           -72.509756
# std          NaN      9.685557                      NaN            10.393860
# min          NaN     -5.000000                      NaN           -75.423848
# 25%          NaN      6.000000                      NaN           -73.992062
# 50%          NaN      8.500000                      NaN           -73.981840
# 75%          NaN     12.500000                      NaN           -73.967148
# max          NaN    200.000000                      NaN            40.783472
#
#         latitude_of_pickup  longitude_of_dropoff  latitude_of_dropoff  \
# count         50000.000000          50000.000000         50000.000000
# unique                 NaN                   NaN                  NaN
# top                    NaN                   NaN                  NaN
# freq                   NaN                   NaN                  NaN
# mean             39.933759            -72.504616            39.926251
# std               6.224857             10.407570             6.014737
# min             -74.006893            -84.654241           -74.006377
# 25%              40.734880            -73.991152            40.734372
# 50%              40.752678            -73.980082            40.753372
# 75%              40.767360            -73.963584            40.768167
# max             401.083332             40.851027            43.415190
#
#         no_of_passenger
# count      50000.000000
# unique              NaN
# top                 NaN
# freq                NaN
# mean           1.667840
# std            1.289195
# min            0.000000
# 25%            1.000000
# 50%            1.000000
# 75%            2.000000
# max            6.000000

# %%
####seaborn

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("TaxiFare.csv")

# %%
df.head()
# Out:
#   unique_id  amount      date_time_of_pickup  longitude_of_pickup  \
# 0   26:21.0     4.5  2009-06-15 17:26:21 UTC           -73.844311
# 1   52:16.0    16.9  2010-01-05 16:52:16 UTC           -74.016048
# 2   35:00.0     5.7  2011-08-18 00:35:00 UTC           -73.982738
# 3   30:42.0     7.7  2012-04-21 04:30:42 UTC           -73.987130
# 4   51:00.0     5.3  2010-03-09 07:51:00 UTC           -73.968095
#
#    latitude_of_pickup  longitude_of_dropoff  latitude_of_dropoff  \
# 0           40.721319            -73.841610            40.712278
# 1           40.711303            -73.979268            40.782004
# 2           40.761270            -73.991242            40.750562
# 3           40.733143            -73.991567            40.758092
# 4           40.768008            -73.956655            40.783762
#
#    no_of_passenger
# 0                1
# 1                1
# 2                2
# 3                1
# 4                1

# %%
df=df.drop(["unique_id","date_time_of_pickup"],axis=1)

# %%
df.head()
# Out:
#    amount  longitude_of_pickup  latitude_of_pickup  longitude_of_dropoff  \
# 0     4.5           -73.844311           40.721319            -73.841610
# 1    16.9           -74.016048           40.711303            -73.979268
# 2     5.7           -73.982738           40.761270            -73.991242
# 3     7.7           -73.987130           40.733143            -73.991567
# 4     5.3           -73.968095           40.768008            -73.956655
#
#    latitude_of_dropoff  no_of_passenger
# 0            40.712278                1
# 1            40.782004                1
# 2            40.750562                2
# 3            40.758092                1
# 4            40.783762                1

# %%
####univariate

# %%
sns.countplot(x="amount",data=df)
plt.show()

# %%
sns.countplot(x="no_of_passenger",data=df)
plt.show()

# %%
### EDA reference

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
# %matplotlib inline 
import seaborn as sns 
pd.set_option("display.max_rows",None)
pd.set_option("display.max_columns",None)
import warnings 
warnings.filterwarnings('ignore')

# %%
import pandas as pd 
df=pd.read_csv("TaxiFare.csv")

# %%
df.head()
# Out:
#   unique_id  amount      date_time_of_pickup  longitude_of_pickup  \
# 0   26:21.0     4.5  2009-06-15 17:26:21 UTC           -73.844311
# 1   52:16.0    16.9  2010-01-05 16:52:16 UTC           -74.016048
# 2   35:00.0     5.7  2011-08-18 00:35:00 UTC           -73.982738
# 3   30:42.0     7.7  2012-04-21 04:30:42 UTC           -73.987130
# 4   51:00.0     5.3  2010-03-09 07:51:00 UTC           -73.968095
#
#    latitude_of_pickup  longitude_of_dropoff  latitude_of_dropoff  \
# 0           40.721319            -73.841610            40.712278
# 1           40.711303            -73.979268            40.782004
# 2           40.761270            -73.991242            40.750562
# 3           40.733143            -73.991567            40.758092
# 4           40.768008            -73.956655            40.783762
#
#    no_of_passenger
# 0                1
# 1                1
# 2                2
# 3                1
# 4                1

# %%
df.tail()
# Out:
#       unique_id  amount      date_time_of_pickup  longitude_of_pickup  \
# 49995   25:15.0    15.0  2013-06-12 23:25:15 UTC           -73.999973
# 49996   19:18.0     7.5  2015-06-22 17:19:18 UTC           -73.984756
# 49997   53:00.0     6.9  2011-01-30 04:53:00 UTC           -74.002698
# 49998   09:00.0     4.5  2012-11-06 07:09:00 UTC           -73.946062
# 49999   13:14.0    10.9  2010-01-13 08:13:14 UTC           -73.932603
#
#        latitude_of_pickup  longitude_of_dropoff  latitude_of_dropoff  \
# 49995           40.748531            -74.016899            40.705993
# 49996           40.768211            -73.987366            40.760597
# 49997           40.739428            -73.998108            40.759483
# 49998           40.777567            -73.953450            40.779687
# 49999           40.763805            -73.932603            40.763805
#
#        no_of_passenger
# 49995                1
# 49996                1
# 49997                1
# 49998                2
# 49999                1

# %%
df.head(10)
# Out:
#   unique_id  amount      date_time_of_pickup  longitude_of_pickup  \
# 0   26:21.0     4.5  2009-06-15 17:26:21 UTC           -73.844311
# 1   52:16.0    16.9  2010-01-05 16:52:16 UTC           -74.016048
# 2   35:00.0     5.7  2011-08-18 00:35:00 UTC           -73.982738
# 3   30:42.0     7.7  2012-04-21 04:30:42 UTC           -73.987130
# 4   51:00.0     5.3  2010-03-09 07:51:00 UTC           -73.968095
# 5   50:45.0    12.1  2011-01-06 09:50:45 UTC           -74.000964
# 6   35:00.0     7.5  2012-11-20 20:35:00 UTC           -73.980002
# 7   22:00.0    16.5  2012-01-04 17:22:00 UTC           -73.951300
# 8   10:00.0     9.0  2012-12-03 13:10:00 UTC           -74.006462
# 9   11:00.0     8.9  2009-09-02 01:11:00 UTC           -73.980658
#
#    latitude_of_pickup  longitude_of_dropoff  latitude_of_dropoff  \
# 0           40.721319            -73.841610            40.712278
# 1           40.711303            -73.979268            40.782004
# 2           40.761270            -73.991242            40.750562
# 3           40.733143            -73.991567            40.758092
# 4           40.768008            -73.956655            40.783762
# 5           40.731630            -73.972892            40.758233
# 6           40.751662            -73.973802            40.764842
# 7           40.774138            -73.990095            40.751048
# 8           40.726713            -73.993078            40.731628
# 9           40.733873            -73.991540            40.758138
#
#    no_of_passenger
# 0                1
# 1                1
# 2                2
# 3                1
# 4                1
# 5                1
# 6                1
# 7                1
# 8                1
# 9                2

# %%
df.tail(10)
# Out:
#       unique_id  amount      date_time_of_pickup  longitude_of_pickup  \
# 49990   16:00.0     4.5  2013-07-18 00:16:00 UTC           -74.002857
# 49991   56:19.0    10.5  2013-10-17 19:56:19 UTC           -73.991685
# 49992   41:47.0     6.1  2009-06-06 10:41:47 UTC           -73.984673
# 49993   27:00.0     7.3  2011-04-07 14:27:00 UTC           -73.982363
# 49994   57:00.0     8.5  2012-10-13 19:57:00 UTC           -73.976212
# 49995   25:15.0    15.0  2013-06-12 23:25:15 UTC           -73.999973
# 49996   19:18.0     7.5  2015-06-22 17:19:18 UTC           -73.984756
# 49997   53:00.0     6.9  2011-01-30 04:53:00 UTC           -74.002698
# 49998   09:00.0     4.5  2012-11-06 07:09:00 UTC           -73.946062
# 49999   13:14.0    10.9  2010-01-13 08:13:14 UTC           -73.932603
#
#        latitude_of_pickup  longitude_of_dropoff  latitude_of_dropoff  \
# 49990           40.734137            -74.001610            40.739282
# 49991           40.739494            -73.985357            40.731971
# 49992           40.768434            -73.988215            40.760082
# 49993           40.765060            -73.969167            40.761268
# 49994           40.744832            -73.981567            40.724635
# 49995           40.748531            -74.016899            40.705993
# 49996           40.768211            -73.987366            40.760597
# 49997           40.739428            -73.998108            40.759483
# 49998           40.777567            -73.953450            40.779687
# 49999           40.763805            -73.932603            40.763805
#
#        no_of_passenger
# 49990                1
# 49991                1
# 49992                1
# 49993                1
# 49994                1
# 49995                1
# 49996                1
# 49997                1
# 49998                2
# 49999                1

# %%
df.sample()
# Out:
#       unique_id  amount      date_time_of_pickup  longitude_of_pickup  \
# 18332   14:00.0     5.3  2009-10-22 15:14:00 UTC           -73.963167
#
#        latitude_of_pickup  longitude_of_dropoff  latitude_of_dropoff  \
# 18332           40.775027            -73.952427            40.781445
#
#        no_of_passenger
# 18332                2

# %%
df.sample(10)
# Out:
#       unique_id  amount      date_time_of_pickup  longitude_of_pickup  \
# 37592   41:14.0    28.9  2012-06-16 22:41:14 UTC           -73.993651
# 10690   31:16.0    14.5  2013-09-07 17:31:16 UTC           -74.004497
# 1738    07:43.0    12.9  2012-05-11 22:07:43 UTC           -73.982236
# 12726   52:00.0     5.3  2012-07-16 15:52:00 UTC           -73.981325
# 34067   01:00.0     4.5  2012-08-15 10:01:00 UTC           -73.989897
# 16281   23:00.0     8.0  2014-05-08 14:23:00 UTC           -73.973362
# 10618   07:02.0     4.9  2012-05-08 16:07:02 UTC           -73.979513
# 21414   02:41.0     5.3  2010-01-18 11:02:41 UTC           -73.957321
# 29151   36:00.0    10.5  2013-08-12 08:36:00 UTC           -73.981452
# 40518   19:08.0     7.0  2013-12-27 10:19:08 UTC           -74.009760
#
#        latitude_of_pickup  longitude_of_dropoff  latitude_of_dropoff  \
# 37592           40.745639            -73.958425            40.658204
# 10690           40.724238            -73.996097            40.760811
# 1738            40.756820            -73.982447            40.722452
# 12726           40.783970            -73.981282            40.771775
# 34067           40.752357            -73.996032            40.752350
# 16281           40.749032            -73.990898            40.736087
# 10618           40.766302            -73.992061            40.763986
# 21414           40.779864            -73.966057            40.765287
# 29151           40.781287            -73.963307            40.810752
# 40518           40.701888            -73.992384            40.713395
#
#        no_of_passenger
# 37592                1
# 10690                1
# 1738                 1
# 12726                1
# 34067                1
# 16281                1
# 10618                1
# 21414                1
# 29151                1
# 40518                2

# %%
df.isnull().sum()
# Out:
# unique_id               0
# amount                  0
# date_time_of_pickup     0
# longitude_of_pickup     0
# latitude_of_pickup      0
# longitude_of_dropoff    0
# latitude_of_dropoff     0
# no_of_passenger         0
# dtype: int64

# %%
duplicate=df.duplicated()
print(duplicate.sum())
# Out:
# 0

# %%
df=df.drop("unique_id",axis=1)

# %%
df=df.drop("date_time_of_pickup",axis=1)

# %%
df.head()
# Out:
#    amount  longitude_of_pickup  latitude_of_pickup  longitude_of_dropoff  \
# 0     4.5           -73.844311           40.721319            -73.841610
# 1    16.9           -74.016048           40.711303            -73.979268
# 2     5.7           -73.982738           40.761270            -73.991242
# 3     7.7           -73.987130           40.733143            -73.991567
# 4     5.3           -73.968095           40.768008            -73.956655
#
#    latitude_of_dropoff  no_of_passenger
# 0            40.712278                1
# 1            40.782004                1
# 2            40.750562                2
# 3            40.758092                1
# 4            40.783762                1

# %%
sns.boxplot(x="amount",data=df)
# Out:
# <Axes: xlabel='amount'>

# %%
sns.boxplot(x="no_of_passenger",data=df)
# Out:
# <Axes: xlabel='no_of_passenger'>

# %%
sns.countplot(x="no_of_passenger",data=df)
plt.show()

# %%
plt.hist("longitude_of_pickup",data=df)
plt.show()

# %%
sns.boxplot(x="amount",data=df)
# Out:
# <Axes: xlabel='amount'>
